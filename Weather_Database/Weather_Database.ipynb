# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 752

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b752e06a24786312a462a9d64222df1

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description= city_weather["weather"][0]["description"]
  
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | shelburne
# Processing Record 3 of Set 1 | bengkulu
# Processing Record 4 of Set 1 | saint george
# Processing Record 5 of Set 1 | ambon
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | soyo
# Processing Record 8 of Set 1 | cayenne
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | katsuura
# Processing Record 11 of Set 1 | mimongo
# Processing Record 12 of Set 1 | fortuna
# Processing Record 13 of Set 1 | sibu
# Processing Record 14 of Set 1 | aranos
# Processing Record 15 of Set 1 | lata
# Processing Record 16 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 1 | sadon
# Processing Record 18 of Set 1 | margate
# Processing Record 19 of Set 1 | saint-augustin
# Processing Record 20 of Set 1 | villa carlos paz
# Processing Record 21 of Set 1 | rocha
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | saint-philippe
# Processing Record 24 of Set 1 | kodiak
# Processing Record 25 of Set 1 | biu
# Processing Record 26 of Set 1 | riyadh
# Processing Record 27 of Set 1 | venustiano carranza
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | sobolevo
# Processing Record 30 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 1 | bethel
# Processing Record 32 of Set 1 | ornskoldsvik
# Processing Record 33 of Set 1 | bubaque
# Processing Record 34 of Set 1 | khrebtovaya
# Processing Record 35 of Set 1 | sistranda
# Processing Record 36 of Set 1 | sitka
# Processing Record 37 of Set 1 | hasaki
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | kutum
# Processing Record 40 of Set 1 | hobart
# Processing Record 41 of Set 1 | port alfred
# Processing Record 42 of Set 1 | suntar
# Processing Record 43 of Set 1 | pacific grove
# Processing Record 44 of Set 1 | bardsir
# Processing Record 45 of Set 1 | longyearbyen
# Processing Record 46 of Set 1 | beringovskiy
# Processing Record 47 of Set 1 | rikitea
# Processing Record 48 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 1 | dingle
# Processing Record 50 of Set 1 | east london
# Processing Record 1 of Set 2 | tocopilla
# Processing Record 2 of Set 2 | belmonte
# Processing Record 3 of Set 2 | lebu
# Processing Record 4 of Set 2 | butaritari
# Processing Record 5 of Set 2 | indramayu
# Processing Record 6 of Set 2 | barrow
# Processing Record 7 of Set 2 | salalah
# Processing Record 8 of Set 2 | ayr
# Processing Record 9 of Set 2 | atuona
# Processing Record 10 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 2 | mataura
# Processing Record 13 of Set 2 | souillac
# Processing Record 14 of Set 2 | arraial do cabo
# Processing Record 15 of Set 2 | kalmunai
# Processing Record 16 of Set 2 | esperance
# Processing Record 17 of Set 2 | la ronge
# Processing Record 18 of Set 2 | putina
# Processing Record 19 of Set 2 | kapaa
# Processing Record 20 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 2 | bluff
# Processing Record 22 of Set 2 | mount gambier
# Processing Record 23 of Set 2 | manjacaze
# Processing Record 24 of Set 2 | saskylakh
# Processing Record 25 of Set 2 | mar del plata
# Processing Record 26 of Set 2 | kaitangata
# Processing Record 27 of Set 2 | ribeira grande
# Processing Record 28 of Set 2 | grand gaube
# Processing Record 29 of Set 2 | maniitsoq
# Processing Record 30 of Set 2 | nizwa
# Processing Record 31 of Set 2 | sakaraha
# Processing Record 32 of Set 2 | carnarvon
# Processing Record 33 of Set 2 | victoria
# Processing Record 34 of Set 2 | trelleborg
# Processing Record 35 of Set 2 | itarema
# Processing Record 36 of Set 2 | port lincoln
# Processing Record 37 of Set 2 | port elizabeth
# Processing Record 38 of Set 2 | jacksonville
# Processing Record 39 of Set 2 | avarua
# Processing Record 40 of Set 2 | karla
# Processing Record 41 of Set 2 | gao
# Processing Record 42 of Set 2 | padang
# Processing Record 43 of Set 2 | tiksi
# Processing Record 44 of Set 2 | puerto ayora
# Processing Record 45 of Set 2 | havoysund
# Processing Record 46 of Set 2 | dikson
# Processing Record 47 of Set 2 | neyshabur
# Processing Record 48 of Set 2 | trojes
# Processing Record 49 of Set 2 | yerbogachen
# Processing Record 50 of Set 2 | sambava
# Processing Record 1 of Set 3 | georgetown
# Processing Record 2 of Set 3 | bredasdorp
# Processing Record 3 of Set 3 | chapais
# Processing Record 4 of Set 3 | jalu
# Processing Record 5 of Set 3 | harper
# Processing Record 6 of Set 3 | manokwari
# Processing Record 7 of Set 3 | najran
# Processing Record 8 of Set 3 | mangan
# Processing Record 9 of Set 3 | vaini
# Processing Record 10 of Set 3 | cape town
# Processing Record 11 of Set 3 | castro
# Processing Record 12 of Set 3 | nikolskoye
# Processing Record 13 of Set 3 | taburi
# City not found. Skipping...
# Processing Record 14 of Set 3 | narsaq
# Processing Record 15 of Set 3 | naze
# Processing Record 16 of Set 3 | ambilobe
# Processing Record 17 of Set 3 | krasnyy chikoy
# Processing Record 18 of Set 3 | nelipyno
# Processing Record 19 of Set 3 | sao filipe
# Processing Record 20 of Set 3 | cahir
# Processing Record 21 of Set 3 | saldanha
# Processing Record 22 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 3 | yulara
# Processing Record 24 of Set 3 | tasiilaq
# Processing Record 25 of Set 3 | labuhan
# Processing Record 26 of Set 3 | sept-iles
# Processing Record 27 of Set 3 | hilo
# Processing Record 28 of Set 3 | bambous virieux
# Processing Record 29 of Set 3 | te anau
# Processing Record 30 of Set 3 | ubinskoye
# Processing Record 31 of Set 3 | ullapool
# Processing Record 32 of Set 3 | nanortalik
# Processing Record 33 of Set 3 | pangnirtung
# Processing Record 34 of Set 3 | meulaboh
# Processing Record 35 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 36 of Set 3 | diamantino
# Processing Record 37 of Set 3 | yairipok
# Processing Record 38 of Set 3 | saint stephen
# Processing Record 39 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 3 | olafsvik
# Processing Record 41 of Set 3 | betulia
# Processing Record 42 of Set 3 | norman wells
# Processing Record 43 of Set 3 | severo-kurilsk
# Processing Record 44 of Set 3 | kristiinankaupunki
# Processing Record 45 of Set 3 | sao raimundo das mangabeiras
# Processing Record 46 of Set 3 | touros
# Processing Record 47 of Set 3 | progreso
# Processing Record 48 of Set 3 | macaboboni
# City not found. Skipping...
# Processing Record 49 of Set 3 | tiznit
# Processing Record 50 of Set 3 | mancheral
# Processing Record 1 of Set 4 | balkanabat
# Processing Record 2 of Set 4 | wenling
# Processing Record 3 of Set 4 | iqaluit
# Processing Record 4 of Set 4 | camana
# Processing Record 5 of Set 4 | khatanga
# Processing Record 6 of Set 4 | alpena
# Processing Record 7 of Set 4 | sorland
# Processing Record 8 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 4 | vostryakovo
# Processing Record 11 of Set 4 | cabo san lucas
# Processing Record 12 of Set 4 | ketchikan
# Processing Record 13 of Set 4 | bismarck
# Processing Record 14 of Set 4 | gayny
# Processing Record 15 of Set 4 | shache
# Processing Record 16 of Set 4 | deputatskiy
# Processing Record 17 of Set 4 | sayyan
# Processing Record 18 of Set 4 | cedar city
# Processing Record 19 of Set 4 | turhal
# Processing Record 20 of Set 4 | manaure
# Processing Record 21 of Set 4 | tongliao
# Processing Record 22 of Set 4 | atar
# Processing Record 23 of Set 4 | ekhabi
# Processing Record 24 of Set 4 | henties bay
# Processing Record 25 of Set 4 | mahebourg
# Processing Record 26 of Set 4 | bambamarca
# Processing Record 27 of Set 4 | yellowknife
# Processing Record 28 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 29 of Set 4 | paamiut
# Processing Record 30 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 31 of Set 4 | naica
# Processing Record 32 of Set 4 | el balyana
# City not found. Skipping...
# Processing Record 33 of Set 4 | san ramon
# Processing Record 34 of Set 4 | mackenzie
# Processing Record 35 of Set 4 | khani
# Processing Record 36 of Set 4 | namibe
# Processing Record 37 of Set 4 | foumban
# Processing Record 38 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 39 of Set 4 | senneterre
# Processing Record 40 of Set 4 | jauharabad
# Processing Record 41 of Set 4 | sao jose da coroa grande
# Processing Record 42 of Set 4 | kouango
# Processing Record 43 of Set 4 | acarau
# Processing Record 44 of Set 4 | skjervoy
# Processing Record 45 of Set 4 | riverton
# Processing Record 46 of Set 4 | pemba
# Processing Record 47 of Set 4 | andevoranto
# City not found. Skipping...
# Processing Record 48 of Set 4 | alice springs
# Processing Record 49 of Set 4 | santa rita
# Processing Record 50 of Set 4 | caravelas
# Processing Record 1 of Set 5 | marzuq
# Processing Record 2 of Set 5 | thai binh
# Processing Record 3 of Set 5 | jaisalmer
# Processing Record 4 of Set 5 | rafaela
# Processing Record 5 of Set 5 | ugento
# Processing Record 6 of Set 5 | new norfolk
# Processing Record 7 of Set 5 | torbay
# Processing Record 8 of Set 5 | cherskiy
# Processing Record 9 of Set 5 | sanchursk
# Processing Record 10 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 5 | upernavik
# Processing Record 12 of Set 5 | mukhen
# Processing Record 13 of Set 5 | mao
# Processing Record 14 of Set 5 | satka
# Processing Record 15 of Set 5 | zhangye
# Processing Record 16 of Set 5 | sabang
# Processing Record 17 of Set 5 | portobelo
# Processing Record 18 of Set 5 | kalemie
# Processing Record 19 of Set 5 | zarubino
# Processing Record 20 of Set 5 | ukiah
# Processing Record 21 of Set 5 | omboue
# Processing Record 22 of Set 5 | lubao
# Processing Record 23 of Set 5 | aklavik
# Processing Record 24 of Set 5 | zhigansk
# Processing Record 25 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 5 | bacuit
# City not found. Skipping...
# Processing Record 27 of Set 5 | qaanaaq
# Processing Record 28 of Set 5 | lashio
# Processing Record 29 of Set 5 | vangaindrano
# Processing Record 30 of Set 5 | roald
# Processing Record 31 of Set 5 | dzilam gonzalez
# Processing Record 32 of Set 5 | arman
# Processing Record 33 of Set 5 | esso
# Processing Record 34 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 5 | bilibino
# Processing Record 36 of Set 5 | darlawn
# Processing Record 37 of Set 5 | gat
# Processing Record 38 of Set 5 | iquique
# Processing Record 39 of Set 5 | mabaruma
# Processing Record 40 of Set 5 | khamanon
# Processing Record 41 of Set 5 | boa vista
# Processing Record 42 of Set 5 | ferkessedougou
# Processing Record 43 of Set 5 | dois vizinhos
# Processing Record 44 of Set 5 | bathsheba
# Processing Record 45 of Set 5 | marathon
# Processing Record 46 of Set 5 | mattawa
# Processing Record 47 of Set 5 | bontang
# Processing Record 48 of Set 5 | kisangani
# Processing Record 49 of Set 5 | muravlenko
# Processing Record 50 of Set 5 | sipe sipe
# Processing Record 1 of Set 6 | haines junction
# Processing Record 2 of Set 6 | juneau
# Processing Record 3 of Set 6 | kayerkan
# Processing Record 4 of Set 6 | tuktoyaktuk
# Processing Record 5 of Set 6 | hamilton
# Processing Record 6 of Set 6 | anadyr
# Processing Record 7 of Set 6 | scottsbluff
# Processing Record 8 of Set 6 | la paz
# Processing Record 9 of Set 6 | san quintin
# Processing Record 10 of Set 6 | lasa
# Processing Record 11 of Set 6 | bonthe
# Processing Record 12 of Set 6 | kavaratti
# Processing Record 13 of Set 6 | asau
# Processing Record 14 of Set 6 | nome
# Processing Record 15 of Set 6 | murud
# Processing Record 16 of Set 6 | qaqortoq
# Processing Record 17 of Set 6 | kikuyu
# Processing Record 18 of Set 6 | cockburn town
# Processing Record 19 of Set 6 | cidreira
# Processing Record 20 of Set 6 | airai
# Processing Record 21 of Set 6 | kyren
# Processing Record 22 of Set 6 | brae
# Processing Record 23 of Set 6 | thompson
# Processing Record 24 of Set 6 | vardo
# Processing Record 25 of Set 6 | ilulissat
# Processing Record 26 of Set 6 | chushan
# Processing Record 27 of Set 6 | oranjestad
# Processing Record 28 of Set 6 | french harbor
# Processing Record 29 of Set 6 | russell
# Processing Record 30 of Set 6 | port hedland
# Processing Record 31 of Set 6 | bendigo
# Processing Record 32 of Set 6 | fukue
# Processing Record 33 of Set 6 | waipawa
# Processing Record 34 of Set 6 | westport
# Processing Record 35 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 6 | liverpool
# Processing Record 37 of Set 6 | tsabong
# Processing Record 38 of Set 6 | kanniyakumari
# Processing Record 39 of Set 6 | tabuk
# Processing Record 40 of Set 6 | hualmay
# Processing Record 41 of Set 6 | babstovo
# Processing Record 42 of Set 6 | borba
# Processing Record 43 of Set 6 | faanui
# Processing Record 44 of Set 6 | anthili
# Processing Record 45 of Set 6 | savannah bight
# Processing Record 46 of Set 6 | leningradskiy
# Processing Record 47 of Set 6 | ahipara
# Processing Record 48 of Set 6 | san patricio
# Processing Record 49 of Set 6 | hami
# Processing Record 50 of Set 6 | aykhal
# Processing Record 1 of Set 7 | svetlyy
# Processing Record 2 of Set 7 | husavik
# Processing Record 3 of Set 7 | komsomolskiy
# Processing Record 4 of Set 7 | faya
# Processing Record 5 of Set 7 | lazaro cardenas
# Processing Record 6 of Set 7 | chaplygin
# Processing Record 7 of Set 7 | lethem
# Processing Record 8 of Set 7 | maputo
# Processing Record 9 of Set 7 | danshui
# Processing Record 10 of Set 7 | vaitape
# Processing Record 11 of Set 7 | clyde river
# Processing Record 12 of Set 7 | chuy
# Processing Record 13 of Set 7 | honiara
# Processing Record 14 of Set 7 | yongan
# Processing Record 15 of Set 7 | hithadhoo
# Processing Record 16 of Set 7 | saint-denis
# Processing Record 17 of Set 7 | kavieng
# Processing Record 18 of Set 7 | gizo
# Processing Record 19 of Set 7 | velikiy ustyug
# Processing Record 20 of Set 7 | lysyye gory
# Processing Record 21 of Set 7 | puerto madero
# Processing Record 22 of Set 7 | krasnyye baki
# Processing Record 23 of Set 7 | port shepstone
# Processing Record 24 of Set 7 | dutlwe
# Processing Record 25 of Set 7 | piryion
# City not found. Skipping...
# Processing Record 26 of Set 7 | provideniya
# Processing Record 27 of Set 7 | khormuj
# City not found. Skipping...
# Processing Record 28 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 29 of Set 7 | morros
# Processing Record 30 of Set 7 | vestmannaeyjar
# Processing Record 31 of Set 7 | egvekinot
# Processing Record 32 of Set 7 | coquimbo
# Processing Record 33 of Set 7 | rio gallegos
# Processing Record 34 of Set 7 | vila franca do campo
# Processing Record 35 of Set 7 | nelson bay
# Processing Record 36 of Set 7 | port-gentil
# Processing Record 37 of Set 7 | sao gabriel da cachoeira
# Processing Record 38 of Set 7 | ampanihy
# Processing Record 39 of Set 7 | rio grande
# Processing Record 40 of Set 7 | codrington
# Processing Record 41 of Set 7 | iringa
# Processing Record 42 of Set 7 | krasnomayskiy
# Processing Record 43 of Set 7 | merritt island
# Processing Record 44 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 45 of Set 7 | sao miguel do tapuio
# Processing Record 46 of Set 7 | greenwood
# Processing Record 47 of Set 7 | vaasa
# Processing Record 48 of Set 7 | kloulklubed
# Processing Record 49 of Set 7 | ponta do sol
# Processing Record 50 of Set 7 | ancud
# Processing Record 1 of Set 8 | port hawkesbury
# Processing Record 2 of Set 8 | dixon
# Processing Record 3 of Set 8 | tambun
# Processing Record 4 of Set 8 | anderson
# Processing Record 5 of Set 8 | olga
# Processing Record 6 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 7 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 8 of Set 8 | santa lucia
# Processing Record 9 of Set 8 | mahdalynivka
# Processing Record 10 of Set 8 | dubbo
# Processing Record 11 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 8 | urumqi
# Processing Record 13 of Set 8 | tshane
# Processing Record 14 of Set 8 | santa cruz
# Processing Record 15 of Set 8 | marand
# Processing Record 16 of Set 8 | sesheke
# Processing Record 17 of Set 8 | rock springs
# Processing Record 18 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 8 | boende
# Processing Record 20 of Set 8 | ugoofaaru
# Processing Record 21 of Set 8 | ulladulla
# Processing Record 22 of Set 8 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 23 of Set 8 | utete
# Processing Record 24 of Set 8 | otradnoye
# Processing Record 25 of Set 8 | sinegorye
# Processing Record 26 of Set 8 | skibbereen
# Processing Record 27 of Set 8 | saint-leu
# Processing Record 28 of Set 8 | carutapera
# Processing Record 29 of Set 8 | guane
# Processing Record 30 of Set 8 | dano
# Processing Record 31 of Set 8 | honningsvag
# Processing Record 32 of Set 8 | parian dakula
# Processing Record 33 of Set 8 | ugra
# Processing Record 34 of Set 8 | pevek
# Processing Record 35 of Set 8 | khandbari
# Processing Record 36 of Set 8 | kandrian
# Processing Record 37 of Set 8 | north platte
# Processing Record 38 of Set 8 | santa cruz del sur
# Processing Record 39 of Set 8 | flin flon
# Processing Record 40 of Set 8 | okhotsk
# Processing Record 41 of Set 8 | katha
# City not found. Skipping...
# Processing Record 42 of Set 8 | grindavik
# Processing Record 43 of Set 8 | havre-saint-pierre
# Processing Record 44 of Set 8 | ambulu
# Processing Record 45 of Set 8 | ballina
# Processing Record 46 of Set 8 | mocuba
# Processing Record 47 of Set 8 | qurayyat
# Processing Record 48 of Set 8 | maimon
# City not found. Skipping...
# Processing Record 49 of Set 8 | rottenmann
# Processing Record 50 of Set 8 | yenagoa
# Processing Record 1 of Set 9 | yanan
# City not found. Skipping...
# Processing Record 2 of Set 9 | amapa
# Processing Record 3 of Set 9 | ostrovnoy
# Processing Record 4 of Set 9 | clonakilty
# Processing Record 5 of Set 9 | jackson
# Processing Record 6 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 7 of Set 9 | kochki
# Processing Record 8 of Set 9 | saint anthony
# Processing Record 9 of Set 9 | chokurdakh
# Processing Record 10 of Set 9 | san antonio
# Processing Record 11 of Set 9 | tyulgan
# Processing Record 12 of Set 9 | bekwai
# Processing Record 13 of Set 9 | tura
# Processing Record 14 of Set 9 | giraltovce
# Processing Record 15 of Set 9 | praia da vitoria
# Processing Record 16 of Set 9 | vostochnyy
# Processing Record 17 of Set 9 | pahrump
# Processing Record 18 of Set 9 | college
# Processing Record 19 of Set 9 | lugus
# Processing Record 20 of Set 9 | tateyama
# Processing Record 21 of Set 9 | hervey bay
# Processing Record 22 of Set 9 | gazli
# Processing Record 23 of Set 9 | aksu
# Processing Record 24 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 25 of Set 9 | frontera
# Processing Record 26 of Set 9 | hobyo
# Processing Record 27 of Set 9 | laguna
# Processing Record 28 of Set 9 | indian head
# Processing Record 29 of Set 9 | ciudad bolivar
# Processing Record 30 of Set 9 | itupiranga
# Processing Record 31 of Set 9 | epe
# Processing Record 32 of Set 9 | kirakira
# Processing Record 33 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 34 of Set 9 | aasiaat
# Processing Record 35 of Set 9 | ashoknagar
# Processing Record 36 of Set 9 | requena
# Processing Record 37 of Set 9 | huanuco
# Processing Record 38 of Set 9 | san jose
# Processing Record 39 of Set 9 | waiuku
# Processing Record 40 of Set 9 | klaksvik
# Processing Record 41 of Set 9 | tupancireta
# Processing Record 42 of Set 9 | constitucion
# Processing Record 43 of Set 9 | lompoc
# Processing Record 44 of Set 9 | omsukchan
# Processing Record 45 of Set 9 | anyama
# Processing Record 46 of Set 9 | valer
# Processing Record 47 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 9 | katherine
# Processing Record 49 of Set 9 | bandarbeyla
# Processing Record 50 of Set 9 | kingston
# Processing Record 1 of Set 10 | beyneu
# Processing Record 2 of Set 10 | harlingen
# Processing Record 3 of Set 10 | moroto
# Processing Record 4 of Set 10 | ussel
# Processing Record 5 of Set 10 | loa janan
# Processing Record 6 of Set 10 | kangaatsiaq
# Processing Record 7 of Set 10 | luderitz
# Processing Record 8 of Set 10 | qasigiannguit
# Processing Record 9 of Set 10 | tieli
# Processing Record 10 of Set 10 | naqadeh
# Processing Record 11 of Set 10 | carauari
# Processing Record 12 of Set 10 | pemangkat
# Processing Record 13 of Set 10 | burica
# City not found. Skipping...
# Processing Record 14 of Set 10 | tall kayf
# Processing Record 15 of Set 10 | visby
# Processing Record 16 of Set 10 | berlevag
# Processing Record 17 of Set 10 | poum
# Processing Record 18 of Set 10 | galesong
# Processing Record 19 of Set 10 | gamba
# Processing Record 20 of Set 10 | talnakh
# Processing Record 21 of Set 10 | sovetskaya
# Processing Record 22 of Set 10 | minna
# Processing Record 23 of Set 10 | tayoltita
# Processing Record 24 of Set 10 | verkhoyansk
# Processing Record 25 of Set 10 | northam
# Processing Record 26 of Set 10 | demyanovo
# Processing Record 27 of Set 10 | lavrentiya
# Processing Record 28 of Set 10 | vallenar
# Processing Record 29 of Set 10 | izhma
# Processing Record 30 of Set 10 | bria
# Processing Record 31 of Set 10 | kidal
# Processing Record 32 of Set 10 | tokur
# Processing Record 33 of Set 10 | fomboni
# Processing Record 34 of Set 10 | skegness
# Processing Record 35 of Set 10 | mungaa
# Processing Record 36 of Set 10 | bahile
# Processing Record 37 of Set 10 | schmallenberg
# Processing Record 38 of Set 10 | vagay
# Processing Record 39 of Set 10 | arroyo
# Processing Record 40 of Set 10 | burgeo
# Processing Record 41 of Set 10 | viransehir
# Processing Record 42 of Set 10 | san cristobal
# Processing Record 43 of Set 10 | mubende
# Processing Record 44 of Set 10 | tual
# Processing Record 45 of Set 10 | antofagasta
# Processing Record 46 of Set 10 | vao
# Processing Record 47 of Set 10 | ploemeur
# Processing Record 48 of Set 10 | wa
# City not found. Skipping...
# Processing Record 49 of Set 10 | lagoa
# Processing Record 50 of Set 10 | los llanos de aridane
# Processing Record 1 of Set 11 | ola
# Processing Record 2 of Set 11 | bairiki
# Processing Record 3 of Set 11 | cheuskiny
# City not found. Skipping...
# Processing Record 4 of Set 11 | lavumisa
# Processing Record 5 of Set 11 | brigantine
# Processing Record 6 of Set 11 | mahanoro
# Processing Record 7 of Set 11 | bilma
# Processing Record 8 of Set 11 | baoshan
# Processing Record 9 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 10 of Set 11 | pangody
# Processing Record 11 of Set 11 | auki
# Processing Record 12 of Set 11 | yar-sale
# Processing Record 13 of Set 11 | prestea
# Processing Record 14 of Set 11 | alekseyevskaya
# Processing Record 15 of Set 11 | makakilo city
# Processing Record 16 of Set 11 | sinop
# Processing Record 17 of Set 11 | quatre cocos
# Processing Record 18 of Set 11 | camacha
# Processing Record 19 of Set 11 | mariental
# Processing Record 20 of Set 11 | mastic beach
# Processing Record 21 of Set 11 | peniche
# Processing Record 22 of Set 11 | sainte-thecle
# Processing Record 23 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 24 of Set 11 | tokmak
# Processing Record 25 of Set 11 | nyurba
# Processing Record 26 of Set 11 | hefei
# Processing Record 27 of Set 11 | sabya
# Processing Record 28 of Set 11 | mayor pablo lagerenza
# Processing Record 29 of Set 11 | bayanday
# Processing Record 30 of Set 11 | gurbanesti
# Processing Record 31 of Set 11 | baruun-urt
# Processing Record 32 of Set 11 | half moon bay
# Processing Record 33 of Set 11 | totma
# Processing Record 34 of Set 11 | saint-pierre
# Processing Record 35 of Set 11 | agaro
# Processing Record 36 of Set 11 | aneho
# Processing Record 37 of Set 11 | moussoro
# Processing Record 38 of Set 11 | marsh harbour
# Processing Record 39 of Set 11 | kindu
# Processing Record 40 of Set 11 | pitimbu
# Processing Record 41 of Set 11 | odessa
# Processing Record 42 of Set 11 | notre-dame-du-lac
# Processing Record 43 of Set 11 | chodziez
# Processing Record 44 of Set 11 | mitu
# Processing Record 45 of Set 11 | manggar
# Processing Record 46 of Set 11 | hue
# Processing Record 47 of Set 11 | richards bay
# Processing Record 48 of Set 11 | sataua
# City not found. Skipping...
# Processing Record 49 of Set 11 | teeli
# Processing Record 50 of Set 11 | gwembe
# Processing Record 1 of Set 12 | taoudenni
# Processing Record 2 of Set 12 | thabazimbi
# Processing Record 3 of Set 12 | tisovec
# Processing Record 4 of Set 12 | urubicha
# Processing Record 5 of Set 12 | atkinson
# Processing Record 6 of Set 12 | santa cruz de la palma
# Processing Record 7 of Set 12 | tazovskiy
# Processing Record 8 of Set 12 | lokoja
# Processing Record 9 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 10 of Set 12 | bhola
# Processing Record 11 of Set 12 | ayan
# Processing Record 12 of Set 12 | aiquile
# Processing Record 13 of Set 12 | sipoo
# Processing Record 14 of Set 12 | severo-yeniseyskiy
# Processing Record 15 of Set 12 | charters towers
# Processing Record 16 of Set 12 | ceglie messapica
# Processing Record 17 of Set 12 | palm coast
# Processing Record 18 of Set 12 | pavlodar
# Processing Record 19 of Set 12 | sakaiminato
# Processing Record 20 of Set 12 | khonsa
# Processing Record 21 of Set 12 | paks
# Processing Record 22 of Set 12 | himora
# City not found. Skipping...
# Processing Record 23 of Set 12 | areia branca
# Processing Record 24 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 12 | ocos
# Processing Record 26 of Set 12 | nuevo ideal
# Processing Record 27 of Set 12 | ordu
# Processing Record 28 of Set 12 | cleveland
# Processing Record 29 of Set 12 | nabire
# Processing Record 30 of Set 12 | hays
# Processing Record 31 of Set 12 | goderich
# Processing Record 32 of Set 12 | sunrise manor
# Processing Record 33 of Set 12 | krasnovishersk
# Processing Record 34 of Set 12 | port hardy
# Processing Record 35 of Set 12 | rabo de peixe
# Processing Record 36 of Set 12 | okahandja
# Processing Record 37 of Set 12 | rawson
# Processing Record 38 of Set 12 | ahuimanu
# Processing Record 39 of Set 12 | roseburg
# Processing Record 40 of Set 12 | shwebo
# Processing Record 41 of Set 12 | yilan
# Processing Record 42 of Set 12 | emba
# Processing Record 43 of Set 12 | broome
# Processing Record 44 of Set 12 | jasper
# Processing Record 45 of Set 12 | dustlik
# Processing Record 46 of Set 12 | nong khai
# Processing Record 47 of Set 12 | vryburg
# Processing Record 48 of Set 12 | belle fourche
# Processing Record 49 of Set 12 | gaujani
# Processing Record 50 of Set 12 | yatou
# Processing Record 1 of Set 13 | geraldton
# Processing Record 2 of Set 13 | kenai
# Processing Record 3 of Set 13 | nemuro
# Processing Record 4 of Set 13 | keetmanshoop
# Processing Record 5 of Set 13 | manica
# Processing Record 6 of Set 13 | gimli
# Processing Record 7 of Set 13 | akyab
# Processing Record 8 of Set 13 | jaque
# Processing Record 9 of Set 13 | moose factory
# Processing Record 10 of Set 13 | careiro da varzea
# Processing Record 11 of Set 13 | santa ana
# Processing Record 12 of Set 13 | alnashi
# Processing Record 13 of Set 13 | tuatapere
# Processing Record 14 of Set 13 | coihaique
# Processing Record 15 of Set 13 | yuzhno-kurilsk
# Processing Record 16 of Set 13 | qui nhon
# Processing Record 17 of Set 13 | borlange
# City not found. Skipping...
# Processing Record 18 of Set 13 | obidos
# Processing Record 19 of Set 13 | ust-kuyga
# Processing Record 20 of Set 13 | maloy
# Processing Record 21 of Set 13 | nueva granada
# Processing Record 22 of Set 13 | nouadhibou
# Processing Record 23 of Set 13 | luanda
# Processing Record 24 of Set 13 | isangel
# Processing Record 25 of Set 13 | hambantota
# Processing Record 26 of Set 13 | bull savanna
# Processing Record 27 of Set 13 | guarapari
# Processing Record 28 of Set 13 | gaya
# Processing Record 29 of Set 13 | mayumba
# Processing Record 30 of Set 13 | trofors
# Processing Record 31 of Set 13 | tabas
# Processing Record 32 of Set 13 | kui buri
# Processing Record 33 of Set 13 | bonavista
# Processing Record 34 of Set 13 | coahuayana
# Processing Record 35 of Set 13 | gusau
# Processing Record 36 of Set 13 | dickinson
# Processing Record 37 of Set 13 | araripina
# Processing Record 38 of Set 13 | vila velha
# Processing Record 39 of Set 13 | morehead
# Processing Record 40 of Set 13 | nexo
# Processing Record 41 of Set 13 | celestun
# Processing Record 42 of Set 13 | the valley
# Processing Record 43 of Set 13 | merrill
# Processing Record 44 of Set 13 | preobrazheniye
# Processing Record 45 of Set 13 | islahiye
# Processing Record 46 of Set 13 | pinyug
# Processing Record 47 of Set 13 | merauke
# Processing Record 48 of Set 13 | mantua
# Processing Record 49 of Set 13 | mehamn
# Processing Record 50 of Set 13 | lorengau
# Processing Record 1 of Set 14 | sola
# Processing Record 2 of Set 14 | yefira
# City not found. Skipping...
# Processing Record 3 of Set 14 | sicamous
# Processing Record 4 of Set 14 | ust-nera
# Processing Record 5 of Set 14 | plouzane
# Processing Record 6 of Set 14 | humaita
# Processing Record 7 of Set 14 | roebourne
# Processing Record 8 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 9 of Set 14 | talaya
# Processing Record 10 of Set 14 | cabedelo
# Processing Record 11 of Set 14 | aloleng
# Processing Record 12 of Set 14 | eureka
# Processing Record 13 of Set 14 | envira
# Processing Record 14 of Set 14 | evensk
# Processing Record 15 of Set 14 | tobolsk
# Processing Record 16 of Set 14 | baykalovo
# Processing Record 17 of Set 14 | karakendzha
# City not found. Skipping...
# Processing Record 18 of Set 14 | dicabisagan
# Processing Record 19 of Set 14 | san nicolas
# Processing Record 20 of Set 14 | yantal
# Processing Record 21 of Set 14 | calvinia
# Processing Record 22 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 23 of Set 14 | waiouru
# Processing Record 24 of Set 14 | suicheng
# Processing Record 25 of Set 14 | parabel
# Processing Record 26 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 27 of Set 14 | davila
# Processing Record 28 of Set 14 | nova olimpia
# Processing Record 29 of Set 14 | esik
# Processing Record 30 of Set 14 | porto empedocle
# Processing Record 31 of Set 14 | linxia
# Processing Record 32 of Set 14 | pangai
# Processing Record 33 of Set 14 | iracoubo
# Processing Record 34 of Set 14 | jimani
# Processing Record 35 of Set 14 | pascagoula
# Processing Record 36 of Set 14 | sakakah
# Processing Record 37 of Set 14 | masuguru
# Processing Record 38 of Set 14 | iranshahr
# Processing Record 39 of Set 14 | winnemucca
# Processing Record 40 of Set 14 | chaihe
# Processing Record 41 of Set 14 | morondava
# Processing Record 42 of Set 14 | vanimo
# Processing Record 43 of Set 14 | san rafael
# Processing Record 44 of Set 14 | marshfield
# Processing Record 45 of Set 14 | japura
# Processing Record 46 of Set 14 | pringsewu
# Processing Record 47 of Set 14 | shetpe
# Processing Record 48 of Set 14 | tarko-sale
# Processing Record 49 of Set 14 | brabova
# Processing Record 50 of Set 14 | sur
# Processing Record 1 of Set 15 | pijijiapan
# Processing Record 2 of Set 15 | tharrawaddy
# City not found. Skipping...
# Processing Record 3 of Set 15 | voslobeni
# Processing Record 4 of Set 15 | cozumel
# Processing Record 5 of Set 15 | alofi
# Processing Record 6 of Set 15 | hay river
# Processing Record 7 of Set 15 | yashkul
# Processing Record 8 of Set 15 | xichang
# Processing Record 9 of Set 15 | bijar
# Processing Record 10 of Set 15 | shihezi
# Processing Record 11 of Set 15 | mareeba
# Processing Record 12 of Set 15 | garowe
# Processing Record 13 of Set 15 | hukuntsi
# Processing Record 14 of Set 15 | wattegama
# Processing Record 15 of Set 15 | hostotipaquillo
# Processing Record 16 of Set 15 | kawambwa
# Processing Record 17 of Set 15 | dunedin
# Processing Record 18 of Set 15 | malindi
# Processing Record 19 of Set 15 | tagusao
# Processing Record 20 of Set 15 | muncar
# Processing Record 21 of Set 15 | martapura
# Processing Record 22 of Set 15 | summerland
# Processing Record 23 of Set 15 | magadan
# Processing Record 24 of Set 15 | zarya
# Processing Record 25 of Set 15 | vidim
# Processing Record 26 of Set 15 | holland
# Processing Record 27 of Set 15 | sivas
# Processing Record 28 of Set 15 | yanchukan
# City not found. Skipping...
# Processing Record 29 of Set 15 | wufeng
# Processing Record 30 of Set 15 | fort nelson
# Processing Record 31 of Set 15 | aras
# Processing Record 32 of Set 15 | mwene-ditu
# Processing Record 33 of Set 15 | gursu
# Processing Record 34 of Set 15 | ponta delgada
# Processing Record 35 of Set 15 | churapcha
# Processing Record 36 of Set 15 | illapel
# Processing Record 37 of Set 15 | bolshaya rechka
# Processing Record 38 of Set 15 | kibala
# Processing Record 39 of Set 15 | port macquarie
# Processing Record 40 of Set 15 | maceio
# Processing Record 41 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 15 | warrington
# Processing Record 43 of Set 15 | bentiu
# Processing Record 44 of Set 15 | abu dhabi
# Processing Record 45 of Set 15 | satipo
# Processing Record 46 of Set 15 | rognan
# Processing Record 47 of Set 15 | babanusah
# City not found. Skipping...
# Processing Record 48 of Set 15 | vrangel
# Processing Record 49 of Set 15 | marquette
# Processing Record 50 of Set 15 | pisco
# Processing Record 1 of Set 16 | asyut
# Processing Record 2 of Set 16 | batemans bay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Check number of cities
len(city_data)
# Out:
# 695

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Jamestown      US  42.0970  -79.2353     20.52        51         100
# 1     Shelburne      CA  44.0787  -80.2041      5.67        88         100
# 2      Bengkulu      ID  -3.8004  102.2655     76.21        86         100
# 3  Saint George      US  37.1041 -113.5841     44.94        29           0
# 4         Ambon      ID  -3.6954  128.1814     89.74        58          20
# 5      Hermanus      ZA -34.4187   19.2345     64.80        72           1
# 6          Soyo      AO  -6.1349   12.3689     76.69        83          73
# 7       Cayenne      GF   4.9333  -52.3333     79.09        88         100
# 8  Punta Arenas      CL -53.1500  -70.9167     46.51        71           0
# 9      Katsuura      JP  35.1333  140.3000     47.19        41          97
#
#    Wind Speed Current Description
# 0        3.44                mist
# 1        7.52     overcast clouds
# 2        3.76     overcast clouds
# 3        4.00           clear sky
# 4        8.05          few clouds
# 5       18.14           clear sky
# 6        2.08       broken clouds
# 7        7.00     overcast clouds
# 8        3.44           clear sky
# 9       11.21     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
